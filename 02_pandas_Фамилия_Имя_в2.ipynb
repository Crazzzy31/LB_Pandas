# %% [markdown]
# <a href="https://colab.research.google.com/github/Crazzzy31/LB_Pandas/blob/main/02_pandas_%D0%A4%D0%B0%D0%BC%D0%B8%D0%BB%D0%B8%D1%8F_%D0%98%D0%BC%D1%8F_%D0%B22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2

# %%
import pandas as pd
import numpy as np
# !pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 KB 5.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
df_recipes = pd.read_csv('/content/dataset/recipes_sample.csv')
df_reviews = pd.read_csv('/content/dataset/reviews_sample.csv', index_col=0)

# %%
df_reviews
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
df_recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
df_recipes.dtypes
# Out:
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object

# %%
df_recipes.shape[0]
# Out:
# 30000

# %%
df_recipes.shape[1]
# Out:
# 8

# %%
df_reviews.dtypes
# Out:
# user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %%
df_reviews.shape[0]
# Out:
# 126696

# %%
df_reviews.shape[1]
# Out:
# 5

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print('Кол-во пустых строк в Recipes:',df_recipes.isnull().sum (axis= 1 ).sum())
print('Доля строк в Recipes:', df_recipes.isnull().sum (axis= 1 ).sum()/df_recipes.shape[0])
print('Кол-во пустых строк в Reviews:',df_reviews.isnull().sum (axis= 1 ).sum())
print('Доля строк в Reviews:', df_reviews.isnull().sum (axis= 1 ).sum()/df_reviews.shape[0])
# Out:
# Кол-во пустых строк в Recipes: 20693
# Доля строк в Recipes: 0.6897666666666666
# Кол-во пустых строк в Reviews: 17
# Доля строк в Reviews: 0.00013417945317926376

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print('Среднее значение Reviews.rating:',df_reviews['rating'].mean())
print('Среднее значение Recipes.minutes:', df_recipes['minutes'].mean())
print('Среднее значение Recipes.n_steps:', df_recipes['n_steps'].mean())
print('Среднее значение Recipes.n_ingridients:', df_recipes['n_ingredients'].mean())
# Out:
# Среднее значение Reviews.rating: 4.410802235271832
# Среднее значение Recipes.minutes: 123.35813333333333
# Среднее значение Recipes.n_steps: 9.805582137161085
# Среднее значение Recipes.n_ingridients: 9.008285984848484

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
df_recipes['name'].sample(n=10)
# Out:
# 5151                   cheese sandwiches  mountain fashion
# 11923                         german peasant style chicken
# 18893                                       nuts and holly
# 9501     disneyland s blue bayou monte cristo sandwich ...
# 18259                         multigrain whole wheat bread
# 25215                       spiced applesauce mini muffins
# 21378                            potato and apple pancakes
# 29993                            zuni caf zucchini pickles
# 22257                      raw pack peaches in light syrup
# 4184              buttermilk and beer battered onion rings
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
df_reviews.reset_index()
# Out:
#           index     user_id  recipe_id        date  rating  \
# 0        370476       21752      57993  2003-05-01       5
# 1        624300      431813     142201  2007-09-16       5
# 2        187037      400708     252013  2008-01-10       4
# 3        706134  2001852463     404716  2017-12-11       5
# 4        312179       95810     129396  2008-03-14       5
# ...         ...         ...        ...         ...     ...
# 126691  1013457     1270706     335534  2009-05-17       4
# 126692   158736     2282344       8701  2012-06-03       0
# 126693  1059834      689540     222001  2008-04-08       5
# 126694   453285  2000242659     354979  2015-06-02       5
# 126695   691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
df_recipes[(df_recipes['minutes'] <= 20) & (df_recipes['n_ingredients'] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
df_recipes['submitted'] = pd.to_datetime(df_recipes.submitted)

# %%
df_recipes.dtypes
# Out:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
df_recipes[(df_recipes['submitted']).dt.year <= 2010]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
df_recipes = df_recipes.assign(description_length=df_recipes['description'].str.len())

# %%
df_recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
df_recipes['name'] = df_recipes['name'].str.title()
df_recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
df_recipes['name_word_count'] = df_recipes['name'].str.split().apply(len)
df_recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
contributor_group = df_recipes.groupby('contributor_id')['name'].count()
print('Максимальное кол-во рецептов у id', contributor_group.idxmax(), 'и равно', contributor_group.max())
# Out:
# Максимальное кол-во рецептов у id 89831 и равно 421

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
df_reviews
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
reviews_group = df_reviews.groupby('recipe_id')['rating'].mean()
print(reviews_group)
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64

# %%
print('кол-во рецептов без отзывов =', reviews_group.isna().sum())
# Out:
# кол-во рецептов без отзывов = 0

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
df_reviews['date'] = pd.to_datetime(df_reviews['date'])
print(df_reviews.groupby(df_reviews['date'].dt.year)['user_id'].count())
# Out:
# date
# 2000       13
# 2001      305
# 2002     2494
# 2003     3879
# 2004     5070
# 2005     7577
# 2006     9964
# 2007    15634
# 2008    18614
# 2009    17672
# 2010    12094
# 2011     8118
# 2012     6095
# 2013     5679
# 2014     3445
# 2015     2715
# 2016     2071
# 2017     2926
# 2018     2331
# Name: user_id, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
merged_df = pd.merge(df_reviews, df_recipes, left_on='recipe_id', right_on='id')
print(merged_df[['id', 'name', 'user_id', 'rating']])
empty_rating = merged_df.isna().sum()
print('кол-во рецептов без отзывов =', empty_rating.rating)
# Out:
#             id                                    name  user_id  rating
# 0        57993                    Salmon With Tomatoes    21752       5
# 1        57993                    Salmon With Tomatoes    86359       5
# 2        57993                    Salmon With Tomatoes    67026       5
# 3        57993                    Salmon With Tomatoes   371697       5
# 4        57993                    Salmon With Tomatoes   175286       5
# ...        ...                                     ...      ...     ...
# 126691   94096                     Vegetable Pasta Pie   157617       5
# 126692  368208                    Crockery Pot Delight  1207345       2
# 126693  154964        Apple Cider Cheesecake   No Cook   357323       5
# 126694  187418                Winter Vegetable Lasagna   160974       5
# 126695  296868  G Nut Special Sauce And Sweet Potatoes    95743       4
#
# [126696 rows x 4 columns]
# кол-во рецептов без отзывов = 0

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
reviews_count = df_reviews.groupby('recipe_id')['rating'].count()
reviews_count_df = reviews_count.reset_index()
reviews_count_df = reviews_count_df.rename(columns={'rating' : 'review_count'})
merged_rating_df = pd.merge(reviews_count_df, df_recipes, left_on='recipe_id', right_on='id')
print(merged_rating_df[['recipe_id', 'name', 'review_count']])
# Out:
#        recipe_id                                        name  review_count
# 0             48                            Boston Cream Pie             2
# 1             55  Betty Crocker S Southwestern Guacamole Dip             4
# 2             66                 Black Coffee Barbecue Sauce            18
# 3             91              Brown Rice And Vegetable Pilaf             4
# 4             94                       Blueberry Buttertarts             4
# ...          ...                                         ...           ...
# 28095     536547                         Cauliflower Ceviche             1
# 28096     536610               Miracle Home Made Puff Pastry             1
# 28097     536728                       Gluten Free  Vegemite             1
# 28098     536729                Creole Watermelon Feta Salad             4
# 28099     536747                          Lemon Pom Pom Cake             4
#
# [28100 rows x 3 columns]

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
reviews_group_df = reviews_group.reset_index()
reviews_group_df = reviews_group_df.rename(columns={'rating' : 'rating_average'})
merged_average_rating_df = pd.merge(reviews_group_df, df_recipes, left_on='recipe_id', right_on='id')
year_average = merged_average_rating_df[['submitted', 'rating_average']]
year_average['submitted'] = year_average['submitted'].dt.year
year_average_group = year_average.groupby('submitted')['rating_average'].mean()
df_year_average_group = year_average_group.reset_index()
df_year_average_group = df_year_average_group.sort_values('rating_average', ascending=True)
print(df_year_average_group)
# Out:
#     submitted  rating_average
# 18       2017        2.707071
# 19       2018        3.343750
# 17       2016        3.456522
# 0        1999        4.058786
# 16       2015        4.064969
# 1        2000        4.168185
# 2        2001        4.245481
# 3        2002        4.281093
# 14       2013        4.345621
# 7        2006        4.355206
# 6        2005        4.355216
# 9        2008        4.360928
# 10       2009        4.360969
# 8        2007        4.363256
# 11       2010        4.369973
# 4        2003        4.380103
# 12       2011        4.388443
# 15       2014        4.400553
# 5        2004        4.402897
# 13       2012        4.419341
# <ipython-input-141-b4e204ace1e5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
df_recipes = df_recipes.sort_values('name_word_count', ascending=False)
df_recipes.to_csv('recipes_update.csv', index = False)

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
writer = pd.ExcelWriter('5.3.xlsx', engine='xlsxwriter')
merged_df[['id', 'name', 'user_id', 'rating']].to_excel(writer, sheet_name='Рецепты с оценками', index=False)
merged_rating_df[['recipe_id', 'name', 'review_count']].to_excel(writer, sheet_name = 'Количество отзывов про рецептам', index = False)
writer.save()

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
